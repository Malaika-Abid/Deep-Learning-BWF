# %%
#Broadcasting in NumPy

# %%
import numpy as np

# %%
arr1=np.array([1,23,4,45])
arr2=np.array([1,45,6,34])
c=arr1*arr2
c
# Out:
# array([   1, 1035,   24, 1530])

# %%
#Single dimension array 
a= 5
c=arr1+a
c
# Out:
# array([ 6, 28,  9, 50])

# %%
#Two Dimension array
a=np.array([[1,23,4],[23,44,56]])
print(a)
b=2
d=a + b
d
# Out:
# [[ 1 23  4]
#  [23 44 56]]
# array([[ 3, 25,  6],
#        [25, 46, 58]])

# %%
import matplotlib.pyplot as plt

# %%
x= np.arange(0,2*np.pi,1)
y= np.sin(2*x)
z=np.cos(2*x)
plt.plot(x,y)
plt.plot(x,z)

plt.legend(['Sin','Cos'])
plt.show()

# %%
a=np.array([[1],[2]])
b=np.array([[1,2,3],[2,4,5]])
b
a*b
# Out:
# array([[ 1,  2,  3],
#        [ 4,  8, 10]])

# %%
v= np.reshape(a,(1,2))
v
# Out:
# array([[1, 2]])

# %%
c=v*a

# %%
c
# Out:
# array([[1, 2],
#        [2, 4]])

# %%
arr1= np.array([[1,2,3],[0,4,2]])
arr2=np.array([1,3,4])
c= arr1 +arr2
c
# Out:
# array([[2, 5, 7],
#        [1, 7, 6]])
